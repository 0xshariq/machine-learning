# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sheryanalysis as sh
from sklearn.preprocessing import StandardScaler
from scipy.stats import pearsonr,chi2_contingency
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# ## EDA

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='str')

# %%
df.shape
# Out:
# (918, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    str
#  2   ChestPainType   918 non-null    str
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    str
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    str
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    str
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 86.2 KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['HeartDisease'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='HeartDisease'>

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
def plotting(var,num):
    plt.subplot(2,2,num)
    sns.histplot(df[var],kde=True)

plotting('Age',1)
plotting('RestingBP',2)
plotting('Cholesterol',3)
plotting('MaxHR',4)
plt.tight_layout()

# %%
ch_mean = df.loc[df['Cholesterol'] != 0, 'Cholesterol'].mean()
ch_mean
# Out:
# np.float64(244.6353887399464)

# %%
df['Cholesterol'] = df['Cholesterol'].replace(0,ch_mean,inplace=True).round(2)
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140        289.0          0     Normal
# 1     49   F           NAP        160        180.0          0     Normal
# 2     37   M           ATA        130        283.0          0         ST
# 3     48   F           ASY        138        214.0          0     Normal
# 4     54   M           NAP        150        195.0          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110        264.0          0     Normal
# 914   68   M           ASY        144        193.0          1     Normal
# 915   57   M           ASY        130        131.0          0     Normal
# 916   57   F           ATA        130        236.0          0        LVH
# 917   38   M           NAP        138        175.0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df['Cholesterol'].value_counts()
# Out:
# Cholesterol
# 244.64    172
# 254.00     11
# 223.00     10
# 220.00     10
# 211.00      9
#          ...
# 353.00      1
# 278.00      1
# 157.00      1
# 176.00      1
# 131.00      1
# Name: count, Length: 222, dtype: int64

# %%
resting_bp_mean = df.loc[df['RestingBP'] != 0, 'RestingBP'].mean()
df['RestingBP'] = df['RestingBP'].replace(0,ch_mean,inplace=True).round(2)
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA      140.0        289.0          0     Normal
# 1     49   F           NAP      160.0        180.0          0     Normal
# 2     37   M           ATA      130.0        283.0          0         ST
# 3     48   F           ASY      138.0        214.0          0     Normal
# 4     54   M           NAP      150.0        195.0          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA      110.0        264.0          0     Normal
# 914   68   M           ASY      144.0        193.0          1     Normal
# 915   57   M           ASY      130.0        131.0          0     Normal
# 916   57   F           ATA      130.0        236.0          0        LVH
# 917   38   M           NAP      138.0        175.0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
plotting('Age',1)
plotting('RestingBP',2)
plotting('Cholesterol',3)
plotting('MaxHR',4)
plt.tight_layout()

# %%
sh.analyze(df)
# Out:
# 🔍 Basic Analysis Report
# ------------------------------------------------------------
# 📏 Shape: (918, 12)
# 🧱 Columns: ['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope', 'HeartDisease']
#
# ✅ No null values found
#
# 🔠 Categorical Columns: ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope', 'HeartDisease']
#
# 🔢 Numerical Columns: ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
# {'shape': (918, 12),
#  'columns': ['Age',
#   'Sex',
#   'ChestPainType',
#   'RestingBP',
#   'Cholesterol',
#   'FastingBS',
#   'RestingECG',
#   'MaxHR',
#   'ExerciseAngina',
#   'Oldpeak',
#   'ST_Slope',
#   'HeartDisease'],
#  'dtypes': {'Age': dtype('int64'),
#   'Sex': <StringDtype(storage='python', na_value=nan)>,
#   'ChestPainType': <StringDtype(storage='python', na_value=nan)>,
#   'RestingBP': dtype('float64'),
#   'Cholesterol': dtype('float64'),
# ...

# %%
sns.countplot(x='Sex', data=df,hue='HeartDisease')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x=df['ChestPainType'],hue=df['HeartDisease'])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
sns.countplot(x=df['FastingBS'],hue=df['HeartDisease'])
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
sns.countplot(x=df['RestingECG'],hue=df['HeartDisease'])
# Out:
# <Axes: xlabel='RestingECG', ylabel='count'>

# %%
sns.countplot(x=df['ST_Slope'],hue=df['HeartDisease'])
# Out:
# <Axes: xlabel='ST_Slope', ylabel='count'>

# %%
sns.countplot(x=df['ExerciseAngina'],hue=df['HeartDisease'])
# Out:
# <Axes: xlabel='ExerciseAngina', ylabel='count'>

# %%
sns.boxplot(x='HeartDisease',y='Cholesterol',data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(x='HeartDisease',y='Age',data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
# Categorical features to test against the target
cat_features = [
    'Sex',
    'ChestPainType',
    'FastingBS',
    'RestingECG',
    'ExerciseAngina',
    'ST_Slope'
]

alpha = 0.05

chi2_results = {}

for col in cat_features:
    contingency = pd.crosstab(
        df[col],
        df['HeartDisease']
    )

    chi2_stat, p_val, _, _ = chi2_contingency(contingency)

    decision = (
        'Reject Null (Keep Feature)'
        if p_val < alpha
        else 'Accept Null (Drop Feature)'
    )

    chi2_results[col] = {
        'chi2_statistic': chi2_stat,
        'p_value': p_val,
        'Decision': decision
    }

chi2_df = pd.DataFrame(chi2_results).T
chi2_df = chi2_df.sort_values(by='p_value')

chi2_df
# Out:
#                chi2_statistic   p_value                    Decision
# ST_Slope           355.918443       0.0  Reject Null (Keep Feature)
# ChestPainType      268.067239       0.0  Reject Null (Keep Feature)
# ExerciseAngina     222.259383       0.0  Reject Null (Keep Feature)
# Sex                 84.145101       0.0  Reject Null (Keep Feature)
# FastingBS           64.320679       0.0  Reject Null (Keep Feature)
# RestingECG          10.931469  0.004229  Reject Null (Keep Feature)

# %% [markdown]
# ### Data cleaning and preprocessing

# %%
df_encode = pd.get_dummies(df,drop_first=True).astype(int)
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172        0             0
# 1     49        160          180          0    156        1             1
# 2     37        130          283          0     98        0             0
# 3     48        138          214          0    108        1             1
# 4     54        150          195          0    122        0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132        1             1
# 914   68        144          193          1    141        3             1
# 915   57        130          131          0    115        1             1
# 916   57        130          236          0    174        0             1
# 917   38        138          175          0    173        0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
df_encode['MaxHR_ratio'] = df_encode['MaxHR'] / (220 - df_encode['Age'])
df_encode['Has_ST_Depression'] = (
    df_encode['Oldpeak'] > 0
).astype(int)
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172        0             0
# 1     49        160          180          0    156        1             1
# 2     37        130          283          0     98        0             0
# 3     48        138          214          0    108        1             1
# 4     54        150          195          0    122        0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132        1             1
# 914   68        144          193          1    141        3             1
# 915   57        130          131          0    115        1             1
# 916   57        130          236          0    174        0             1
# 917   38        138          175          0    173        0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
# Numerical features to check against target
numerical_features = [
    'Age',
    'RestingBP',
    'Cholesterol',
    'FastingBS',
    'MaxHR',
    'Oldpeak',
    'MaxHR_ratio'
]

correlations = {
    feature: pearsonr(
        df_encode[feature],
        df_encode['HeartDisease']
    )[0]
    for feature in numerical_features
}

correlation_df = pd.DataFrame(
    list(correlations.items()),
    columns=['Feature', 'Pearson Correlation']
)

correlation_df = correlation_df.sort_values(
    by='Pearson Correlation',
    ascending=False
)

correlation_df
# Out:
#        Feature  Pearson Correlation
# 5      Oldpeak             0.392385
# 0          Age             0.282039
# 3    FastingBS             0.267291
# 1    RestingBP             0.121491
# 2  Cholesterol             0.092586
# 6  MaxHR_ratio            -0.335320
# 4        MaxHR            -0.400421

# %%
numerical_cols = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']

scaler = StandardScaler()

df_encode[numerical_cols] = scaler.fit_transform(
    df_encode[numerical_cols]
)
df_encode
# Out:
#           Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# 0   -1.433140   0.399826     0.834754          0  1.382928 -0.727592
# 1   -0.478484   1.489614    -1.210675          0  0.754157  0.282891
# 2   -1.751359  -0.145068     0.722161          0 -1.525138 -0.727592
# 3   -0.584556   0.290847    -0.572651          0 -1.132156  0.282891
# 4    0.051881   0.944720    -0.929194          0 -0.581981 -0.727592
# ..        ...        ...          ...        ...       ...       ...
# 913 -0.902775  -1.234855     0.365619          0 -0.188999  0.282891
# 914  1.536902   0.617784    -0.966725          1  0.164684  2.303858
# 915  0.370100  -0.145068    -2.130180          0 -0.857069  0.282891
# 916  0.370100  -0.145068    -0.159813          0  1.461525 -0.727592
# 917 -1.645286   0.290847    -1.304502          0  1.422226 -0.727592
#
#      HeartDisease  Sex_M  ChestPainType_ATA  ChestPainType_NAP  \
# 0               0      1                  1                  0
# ...

# %%
plt.figure(figsize=(16, 12))

sns.heatmap(
    df_encode.corr(numeric_only=True),
    annot=True,
    fmt=".2f",
    annot_kws={"size": 8}
)

plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()

plt.show()

# %%
df_encode.to_csv("heart_cleaned.csv", index=False) # Save the cleaned data to a new CSV file
